# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# #### Understanding data

# %%
# Check name of columns
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
# Check the size of data (rows and columns)
df.shape
# Out:
# (1465, 16)

# %%
# Check the data type in columns
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
# Check the data uniqueness and frequency
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# ### Data Wrangling
# #### 1. Change the currency unit "₹"
# #### 2. Change the data type ("object") to the type we need

# %%
df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
df['discounted_price'] = df['discounted_price'].str.replace(",",'')
df['discounted_price'] = df['discounted_price'].astype('float64')

df['actual_price'] = df['actual_price'].str.replace("₹",'')
df['actual_price'] = df['actual_price'].str.replace(",",'')
df['actual_price'] = df['actual_price'].astype('float64')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price discount_percentage rating rating_count  \
# 0        1099.0                 64%    4.2       24,269
# ...

# %%
df.isna().sum() # Always use isna() over isnull()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Some missing values in rating_count.
nan_cols = [i for i in df.columns if df[i].isnull().any()] # This identify the name of the column
rows_with_nan = df[df.isna().any(axis=1)]
rows_with_nan
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price discount_percentage rating rating_count  \
# 282         999.0                 80%    3.0          NaN
# 324         999.0                 75%    5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
# Duplicate the df for operation. Remove the unwanted info in the operation part
df_op = df.copy().drop(['user_name','review_id','img_link','product_link'], axis=1)
# Replace the NaN with 0
df_op['rating_count'] = df_op['rating_count'].fillna(0)
df_fillna_check = df_op.iloc[282]
df_fillna_check
# Out:
# product_id                                                    B0B94JPY2N
# product_name           Amazon Brand - Solimo 65W Fast Charging Braide...
# category               Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                   199.0
# actual_price                                                       999.0
# discount_percentage                                                  80%
# rating                                                               3.0
# rating_count                                                           0
# about_product          USB C to C Cable: This cable has type C connec...
# user_id                                     AE7CFHY23VAJT2FI4NZKKP6GS2UQ
# review_title                The cable works but is not 65W as advertised
# review_content         I have a pd supported car charger and I bought...
# Name: 282, dtype: object

# %%
# Take care of the category. Need to split them
df_op['category'].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                               1
# ...

# %%
df_cat_split = df_op['category'].str.split("|", expand=True).rename(columns={0:'category_1', 1:'category_2', 2:'category_3', 3:'category_4',4:'category_5',5:'category_6', 6:'category_7'})
df_cat_split['category_6'].isna().sum()
# Out:
# 1380

# %% [markdown]
# ##### Total 1465, so we still have 1465-1380 in category_6

# %%
df_cat_split['category_7'].isna().sum()
# Out:
# 1452

# %% [markdown]
# ##### Total 1465, so we only have 13 items in category_7

# %%
rows_with_value_incat7 = df_cat_split[df_cat_split['category_7'].notna()]
rows_with_value_incat7
# Out:
#           category_1              category_2               category_3  \
# 616   OfficeProducts     OfficePaperProducts                    Paper
# 757   OfficeProducts     OfficePaperProducts                    Paper
# 765   OfficeProducts     OfficePaperProducts                    Paper
# 850   OfficeProducts     OfficePaperProducts                    Paper
# 858   OfficeProducts     OfficePaperProducts                    Paper
# 878   OfficeProducts     OfficePaperProducts                    Paper
# 893   OfficeProducts     OfficePaperProducts                    Paper
# 919   OfficeProducts     OfficePaperProducts                    Paper
# 955   OfficeProducts     OfficePaperProducts                    Paper
# 993   OfficeProducts     OfficePaperProducts                    Paper
# 1004  OfficeProducts     OfficePaperProducts                    Paper
# 1005  OfficeProducts     OfficePaperProducts                    Paper
# ...

# %% [markdown]
# ###### Interestingly, except the lst one(1444), all other items are from the similar category ('Pens&Refills')
# ###### According to this result, the category_7 is actually not that important

# %%
def replace_cat(category:str):
    df_op[category] = df_cat_split[category]

for i in range(1,7):
    x = "category_" + str(i)
    replace_cat(x)

df_op.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             379.0
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2280.0
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...            2219.0
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...            1399.0
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2863.0
#
#       actual_price discount_percentage rating rating_count  \
# ...

# %%
df_op.drop(columns = 'category', axis=1, inplace=True)

# %%
df_op['category_1'].value_counts()
# Out:
# category_1
# Electronics              526
# Computers&Accessories    453
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
# Noticed that the user_id column also needs to be split
df_user_split = df_op['user_id'].str.split(',', expand=True).rename(columns={0:'user_1', 1:'user_2', 2:'user_3', 3:'user_4',4:'user_5',5:'user_6', 6:'user_7', 7:'user_8'})
df_user_split.head()

# We can edit the df_op, but I don't thiink we need it for now.
# def replace_user(user_id:str):
#     df_op[user_id] = df_user_split[user_id]

# for i in range(1,9):
#     x = "user_" + str(i)
#     replace_user(x)

# df_op.tail()
# Out:
#                          user_1                        user_2  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q  AHMY5CWJMMK5BJRBBSNLYT3ONILA
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ  AGYYVPDD7YG7FYNBXNGXZJT525AQ
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA  AESFLDV2PT363T2AQLWQOWZ4N3OA
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A  AG5HTSFRRE6NL3M5SGCUQBP7YSCA
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA  AFUGIFH5ZAFXRDSZHM4QB2KPKFUQ
#
#                          user_3                        user_4  \
# 0  AHCTC6ULH4XB6YHDY6PCH2R772LQ  AGYHHIERNXKA6P5T7CZLXKVPT7IQ
# 1  AHONIZU3ICIEHQIGQ6R2VFRSBXOQ  AFPHD2CRPDZMWMBL7WXRSVYWS5JA
# 2  AHTPQRIMGUD4BYR5YIHBH3CCGEFQ  AEUVWXYP5LT7PZLLZENEO2NODPBQ
# 3  AH725ST5NW2Y4JZPKUNTIJCUK2BA  AHV3TXIFCJPMS4D5JATCEUR266MQ
# 4  AFK4NJOLFSJGWLOJIUIAROJF6YVA  AFUOTYRFUXVPEBGIXVZZ7DR3CZUA
#
#                          user_5                        user_6  \
# 0  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  AENGU523SXMOS7JPDTW52PNNVWGQ
# 1  AEZ346GX3HJ4O4XNRPHCNHXQURMQ  AEPSWFPNECKO34PUC7I56ITGXR6Q
# ...

# %%
main = df_op[['category_1', 'category_2', 'category_3', 'category_4','product_id']].rename(columns={'category_1' :'Main Category', 'category_2' : 'Sub-Category', 'product_id':'Products'})
product_by_cat = pd.pivot_table(main, index=['Main Category', 'Sub-Category','category_3', 'category_4'], aggfunc='count')
product_by_cat
# Out:
#                                                                                               Products
# Main Category         Sub-Category            category_3               category_4
# Car&Motorbike         CarAccessories          InteriorAccessories      AirPurifiers&Ionizers         1
# Computers&Accessories Accessories&Peripherals Adapters                 USBtoUSBAdapters              2
#                                               Audio&VideoAccessories   PCHeadsets                    1
#                                                                        PCMicrophones                 2
#                                                                        PCSpeakers                    2
# ...                                                                                                ...
# OfficeProducts        OfficeElectronics       Calculators              Financial&Business            1
# ...

# %%
# category_4 is too detail
main = df_op[['category_1', 'category_2', 'category_3','product_id']].rename(columns={'category_1' :'Main Category', 'category_2' : 'Sub-Category', 'category_3' : 'Sub-Sub-Category','product_id':'Products'})
product_by_cat3 = pd.pivot_table(main, index=['Main Category', 'Sub-Category','Sub-Sub-Category'], aggfunc='count')
product_by_cat3
# Out:
#                                                                         Products
# Main Category         Sub-Category            Sub-Sub-Category
# Car&Motorbike         CarAccessories          InteriorAccessories              1
# Computers&Accessories Accessories&Peripherals Adapters                         2
#                                               Audio&VideoAccessories           7
#                                               Cables&Accessories             240
#                                               HardDiskBags                     3
# ...                                                                          ...
# HomeImprovement       Electrical              CordManagement                   1
# MusicalInstruments    Microphones             Condenser                        2
# OfficeProducts        OfficeElectronics       Calculators                      4
#                       OfficePaperProducts     Paper                           27
# ...

# %%
import matplotlib.pyplot as plt

most_main_items = df_op['category_1'].value_counts().head(10).rename_axis('category_1').reset_index(name='counts')
most_sub_items = df_op['category_2'].value_counts().head(10).rename_axis('category_2').reset_index(name='counts')
miscellaneous_items = df_op['category_3'].value_counts().head(10).rename_axis('category_3').reset_index(name='counts')

colors = sns.color_palette('Set1')
fig = plt.figure(figsize=(10, 4))
bars = plt.barh(most_main_items['category_1'], most_main_items['counts'], color=colors)

for bar, count in zip(bars, most_main_items['counts']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, str(count), va='center', ha='left')

plt.xlabel('Counts')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ##### Based on this figure, there are only 4 categories are ore important than others: Electronics, Computer & Accessories, Home & Kitchen, and Office Product

# %%
most_sub_items = df_op['category_2'].value_counts().head(10).rename_axis('category_2').reset_index(name='counts')

fig = plt.figure(figsize=(10, 4))
bars = plt.barh(most_sub_items['category_2'], most_sub_items['counts'], color=colors)

for bar, count in zip(bars, most_sub_items['counts']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, str(count), va='center', ha='left')

plt.xlabel('Counts')
plt.ylabel('Category')
plt.show()

# %%
fig = plt.figure(figsize=(10, 4))
bars = plt.barh(miscellaneous_items['category_3'], miscellaneous_items['counts'], color=colors)

for bar, count in zip(bars, miscellaneous_items['counts']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, str(count), va='center', ha='left')

plt.xlabel('Counts')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ##### Here, were trying to get the info from the Sub-Sub-Category, but few of them are accessories, it will be better if labelled with main or sub category.

# %%
# Visualize the Top10 based on Sub-Sub-Category. Preparing the Top_10 dataframe
top_10 = product_by_cat3.nlargest(10, product_by_cat3.columns.tolist())
top_10
# Out:
#                                                                                   Products
# Main Category         Sub-Category                   Sub-Sub-Category
# Computers&Accessories Accessories&Peripherals        Cables&Accessories                240
# Home&Kitchen          Kitchen&HomeAppliances         SmallKitchenAppliances            181
# Electronics           HomeTheater,TV&Video           Accessories                        86
#                       Mobiles&Accessories            MobileAccessories                  84
# Home&Kitchen          Kitchen&HomeAppliances         Vacuum,Cleaning&Ironing            82
# Electronics           Mobiles&Accessories            Smartphones&BasicMobiles           77
#                       WearableTechnology             SmartWatches                       76
#                       HomeTheater,TV&Video           Televisions                        69
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 4))

# Convert multi-level index to strings
index_labels = [', '.join(map(str, idx)) for idx in top_10.index]

# Plot the horizontal bar graph and store the bar objects
bars = ax.barh(index_labels, top_10['Products'], color=colors)

# Add labels to each bar
for bar, count in zip(bars, top_10['Products']):
    ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f'{count}', va='center', ha='left')

# Set labels and title
ax.set_xlabel('Counts')
ax.set_ylabel('Category')
plt.title('Counts of Products by Category')
# Out:
# Text(0.5, 1.0, 'Counts of Products by Category')

# %%
# Rating vs Rating Counts
# Do customers tend to leave more reviews for items they like/ don't like?
rating = df_op['rating'].replace('|', np.nan).astype(float)
rating_counts = df_op['rating_count'].str.replace(',','')
rating_counts= rating_counts.fillna(0).astype(int) # Use fillna since there are NaN in the rating_counts
rating_counts
# Out:
# 0       24269
# 1       43994
# 2        7928
# 3       94363
# 4       16905
#         ...
# 1460     1090
# 1461     4118
# 1462      468
# 1463     8031
# 1464     6987
# Name: rating_count, Length: 1465, dtype: int32

# %%
# Visualizing Rating vs Rating Counts
fig = plt.figure(figsize=(6, 4))
sns.scatterplot(x = rating, y = rating_counts)
plt.xlabel('Rating')
plt.ylabel('Number of Ratings')
plt.title('Scatter Plot of Rating vs Counts')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Rating vs Counts')

# %%
# Histogram view
fig = plt.figure(figsize=(6, 4))

# Number of bins decided by Sturges' Formula : int(1 + np.log2(len(x)))
sns.histplot(x = rating, bins=11, kde=True, color='orange')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Rating Distribution')
# Out:
# Text(0.5, 1.0, 'Rating Distribution')

# %% [markdown]
# ##### According to this result. People tend to leave more ratings when they are satisfied with products (~4)

# %%
# Calculate rating for each category_3
df_op['rating'] = df_op['rating'].replace('|', np.nan).astype(float)
rating_cat3 = df_op.groupby('category_3')['rating'].agg(['mean', 'min', 'max'])

# Round the mean rating to 2 decimal places
rating_cat3['mean'] = rating_cat3['mean'].round(2)
rating_cat3
# Out:
#                             mean  min  max
# category_3
# AVReceivers&Amplifiers      4.00  4.0  4.0
# Accessories                 4.00  3.0  4.6
# Adapters                    4.03  3.9  4.3
# Adapters&Multi-Outlets      4.00  4.0  4.0
# AirConditioners             4.30  4.3  4.3
# ...                          ...  ...  ...
# UninterruptedPowerSupplies  3.90  3.9  3.9
# Vacuum,Cleaning&Ironing     4.08  3.1  4.6
# VideoCameras                3.70  3.7  3.7
# WaterHeaters&Geysers        4.08  3.4  4.8
# WaterPurifiers&Accessories  4.05  2.9  4.6
#
# [71 rows x 3 columns]

# %% [markdown]
# ##### Here, we can observe the same trend, the mean value of most ratings are close to 4

# %%
# Check rating in Main Category
fig = plt.subplots(figsize=(6, 4))

sns.boxplot(data=df_op, x='rating', y='category_1', hue ='category_1', palette="Set1")

ax.set_xlabel('Rating')
ax.set_ylabel('Main Category')
ax.set_title('Rating Distribution', y=1)
ax.legend=False

plt.show()

# %%
# Pivot the DataFrame
heatmap_data = df_op.pivot_table(index='category_1', columns='rating', aggfunc='size', fill_value=0)

fig = plt.figure(figsize=(8, 4))
sns.heatmap(heatmap_data, annot=True, fmt="d", linewidths=0.3, linecolor="grey", cmap="RdBu_r")

# This has all 0 value masked
# sns.heatmap(heatmap_data, annot=True, fmt="d", linewidths=0.3, linecolor="grey", cmap="RdBu_r", mask=(heatmap_data == 0), cbar=False)

plt.xlabel('Rating')
plt.ylabel('Category')
plt.title('Heatmap of Ratings by Category')
plt.show()

#### This heatmap shows that most reviews are from Computer, Electronics, Home & kitchen. Also, majority of ratings are around 4

# %%
# Generating wordcloud for selected reviews (electronics)
from wordcloud import WordCloud
df_reviews_electronics = df_op[df_op['category_1'] == 'Electronics']
reviews_electronics = ' '.join(df_reviews_electronics['review_content'].dropna().values)
wordcloud_electronics = WordCloud(width=800, height=400, background_color='white', min_font_size=10).generate(reviews_electronics)
fig = plt.figure(figsize=(8, 4))
plt.imshow(wordcloud_electronics)
plt.axis("off")
plt.show()

# %%
# Generating wordcloud for selected reviews (home&kitchen category with review >= 3.8)
from wordcloud import WordCloud
df_reviews_home_positive = df_op[(df_op['category_1'] == 'Home&Kitchen') & (df_op['rating'] >= 3.8) ]
reviews_home_positive = ' '.join(df_reviews_home_positive['review_content'].dropna().values)
wordcloud_home_postive = WordCloud(width=800, height=400, background_color='white', colormap = 'Set2', min_font_size=10, min_word_length = 2).generate(reviews_home_positive)
plt.figure(figsize=(8, 4))
plt.imshow(wordcloud_home_postive)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Analyze what customers care most in their review. Things like "good", "nice" are not helpful in this analysis
# #### Use the stopword to remove those

# %%
# Modifiy selected reviews (home&kitchen category with review >= 3.8) with stopwords
from wordcloud import WordCloud
stopwords = set()
stopwords.update(["good", "nice", "also", "with", "from", "this", "that", "very", "like", "only", "great"])

wordcloud_home_postive = WordCloud(width=800, height=400, background_color='white', colormap = 'Set2', min_font_size=10, min_word_length = 4, stopwords=stopwords).generate(reviews_home_positive)
plt.figure(figsize=(8, 4))
plt.imshow(wordcloud_home_postive)
plt.axis("off")
plt.show()

# %%
# export the df_op for other usage
df_op.to_csv('processed_data.csv', index =False)
